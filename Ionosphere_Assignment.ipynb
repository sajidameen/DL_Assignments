# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
dataFrame = pd.read_csv("/content/drive/MyDrive/DLAssignments/datasets/ionosphere_data.csv")

# %%
dataFrame.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
dataFrame.shape
# Out:
# (351, 35)

# %%
dataFrame.describe().T
# Out:
#            count      mean       std  min       25%      50%       75%  max
# feature1   351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# feature2   351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# Out:
# feature1
# 2
# feature2
# 1
# feature3
# 219
# feature4
# 269
# feature5
# 204
# feature6
# 259
# feature7
# 231
# feature8
# 260
# feature9
# 244
# feature10
# 267
# feature11
# 246
# feature12
# 269
# feature13
# 238
# feature14
# 266
# feature15
# 234
# feature16
# 270
# feature17
# 254
# feature18
# 280
# feature19
# 254
# feature20
# 266
# feature21
# 248
# feature22
# 265
# feature23
# 248
# feature24
# 264
# feature25
# 256
# feature26
# 273
# feature27
# 256
# feature28
# 281
# feature29
# 244
# feature30
# 266
# feature31
# 243
# feature32
# 263
# feature33
# 245
# feature34
# 263
# label
# 2

# %%
dataFrame.drop(dataFrame.columns[1], inplace=True, axis=1)

# %%
dataFrame.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      g
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      b
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      g
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      b
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
dataFrame.describe()
# Out:
#          feature1    feature3    feature4  ...   feature32   feature33   feature34
# count  351.000000  351.000000  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372  ...   -0.003794    0.349364    0.014480
# std      0.311155    0.497708    0.441435  ...    0.513574    0.522663    0.468337
# min      0.000000   -1.000000   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000    0.871110    0.016310  ...    0.000000    0.409560    0.000000
# 75%      1.000000    1.000000    0.194185  ...    0.200120    0.813765    0.171660
# max      1.000000    1.000000    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %%
dataFrame.isnull().sum()
# Out:
# feature1     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
dataFrame['label'] = [1 if lbl == 'g' else 0 for lbl in dataFrame['label']]

# %%
train_data = dataFrame.sample(frac= 0.6, random_state=125)
test_data = dataFrame.drop(train_data.index)

# %%
train_label = train_data.iloc[:,-1]
train_data = train_data.iloc[:,0:-1]
test_label = test_data.iloc[:,-1]
test_data = test_data.iloc[:,0:-1]

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  ...  feature32  feature33  feature34
# 270         1   1.00000   0.08013  ...   -0.03464    0.92226   -0.03673
# 116         1   1.00000  -0.14754  ...   -0.44262    0.49180   -0.06557
# 135         1   0.89706   0.38235  ...   -0.50735   -0.28676   -0.56618
# 91          1   0.84557  -0.08580  ...   -0.78170   -0.18494   -0.59867
# 100         1   1.00000  -1.00000  ...   -1.00000    0.00000    0.00000
#
# [5 rows x 33 columns]

# %%
train_label
# Out:
# 270    1
# 116    0
# 135    1
# 91     0
# 100    0
#       ..
# 213    1
# 161    1
# 141    1
# 59     0
# 113    1
# Name: label, Length: 211, dtype: int64

# %%
train_data.shape
# Out:
# (211, 33)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label.shape
# Out:
# (211,)

# %%
test_label.shape
# Out:
# (140,)

# %%
train_data = train_data.to_numpy()

# %%
train_label = train_label.to_numpy().astype('float32')

# %%
test_data = test_data.to_numpy()

# %%
test_label = test_label.to_numpy().astype('float32')

# %%
print(type(train_data))
print(type(train_label))
print(type(test_data))
print(type(test_label))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(train_data.dtype)
print(train_label.dtype)
print(test_label.dtype)
print(test_data.dtype)
# Out:
# float64
# float32
# float32
# float64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               4352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 12,673
# Trainable params: 12,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_label, validation_split=0.25, epochs= 100, batch_size = 32)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.6762 - accuracy: 0.5782 - val_loss: 0.5290 - val_accuracy: 0.8113
# Epoch 2/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5389 - accuracy: 0.7878 - val_loss: 0.4755 - val_accuracy: 0.8868
# Epoch 3/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4987 - accuracy: 0.7974 - val_loss: 0.4403 - val_accuracy: 0.9057
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4978 - accuracy: 0.8271 - val_loss: 0.4012 - val_accuracy: 0.9245
# Epoch 5/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4947 - accuracy: 0.8332 - val_loss: 0.3732 - val_accuracy: 0.9245
# Epoch 6/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4087 - accuracy: 0.8549 - val_loss: 0.3471 - val_accuracy: 0.9245
# Epoch 7/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3510 - accuracy: 0.9051 - val_loss: 0.3239 - val_accuracy: 0.9245
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3076 - accuracy: 0.9408 - val_loss: 0.3014 - val_accuracy: 0.9434
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3500 - accuracy: 0.8937 - val_loss: 0.2834 - val_accuracy: 0.9434
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2676 - accuracy: 0.9589 - val_loss: 0.2714 - val_accuracy: 0.9623
# Epoch 11/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3013 - accuracy: 0.9139 - val_loss: 0.2563 - val_accuracy: 0.9623
# Epoch 12/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2553 - accuracy: 0.9391 - val_loss: 0.2496 - val_accuracy: 0.9434
# Epoch 13/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2234 - accuracy: 0.9497 - val_loss: 0.2368 - val_accuracy: 0.9623
# Epoch 14/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2375 - accuracy: 0.9317 - val_loss: 0.2301 - val_accuracy: 0.9623
# Epoch 15/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.
100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0448 - accuracy: 0.9793 - val_loss: 0.2736 - val_accuracy: 0.9623
# Epoch 75/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0379 - accuracy: 0.9922 - val_loss: 0.2569 - val_accuracy: 0.9623
# Epoch 76/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0216 - accuracy: 0.9949 - val_loss: 0.2863 - val_accuracy: 0.9623
# Epoch 77/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9623
# Epoch 78/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0112 - accuracy: 0.9979 - val_loss: 0.2739 - val_accuracy: 0.9623
# Epoch 79/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0171 - accuracy: 0.9922 - val_loss: 0.2820 - val_accuracy: 0.9623
# Epoch 80/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.2816 - val_accuracy: 0.9623
# Epoch 81/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9623
# Epoch 82/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9623
# Epoch 83/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0114 - accuracy: 0.9979 - val_loss: 0.2697 - val_accuracy: 0.9623
# Epoch 84/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.9623
# Epoch 85/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0362 - accuracy: 0.9870 - val_loss: 0.2810 - val_accuracy: 0.9623
# Epoch 86/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2747 - val_accuracy: 0.9623
# Epoch 87/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 0.2582 - val_accuracy: 0.9623
# Epoch 88/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0131 - accuracy: 0.9949 - val_loss: 0.2753 - val_accuracy: 0.9623
# Epoch 89/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.9623
# Epoch 90/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9623
# Epoch 91/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2853 - val_accuracy: 0.9623
# Epoch 92/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9623
# Epoch 93/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9623
# Epoch 94/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2994 - val_accuracy: 0.9623
# Epoch 95/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.2677 - val_accuracy: 0.9811
# Epoch 96/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9623
# Epoch 97/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9623
# Epoch 98/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9623
# Epoch 99/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.9623
# Epoch 100/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3052 - val_accuracy: 0.9623

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(100)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
score = model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3651 - accuracy: 0.9214

# %%
score
# Out:
# [0.3650977611541748, 0.9214285612106323]

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
tf.math.confusion_matrix(
    test_label, y_pred, num_classes=2, weights=None, dtype=tf.dtypes.int32,
    name=None
)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[45, 10],
#        [ 1, 84]], dtype=int32)>

# %%
np.count_nonzero(y_pred)
# Out:
# 94
